# %% [markdown]
# <a href="https://colab.research.google.com/github/pavansaipps2-cmd/ML-Practical_Skill/blob/main/Week2_Skill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("placement_predict_50k_Dataset_cleaned.csv")
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,4))

sns.countplot(data=df, x="Stream")

plt.title("Placement Count by Branch")
plt.xlabel("Branch")
plt.ylabel("Count")

plt.show()

plt.figure(figsize=(6,4))

plt.hist(df["CGPA"].dropna(),
         bins=15,
         color="skyblue",
         edgecolor="black")

plt.title("CGPA Distribution")
plt.xlabel("CGPA")
plt.ylabel("Frequency")

plt.show()

plt.figure(figsize=(12,10)) # Increased figure size

numeric_df = df.select_dtypes(include="number")

corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix,
            annot=True,
            cmap="coolwarm",
            fmt=".2f",
            annot_kws={'size': 8}) # Reduced annotation font size

plt.title("Correlation Heatmap")

plt.show()
