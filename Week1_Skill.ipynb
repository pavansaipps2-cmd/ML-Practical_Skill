# %% [markdown]
# <a href="https://colab.research.google.com/github/pavansaipps2-cmd/ML-Practical_Skill/blob/main/Week1_Skill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# File name
import pandas as pd
CSV_PATH = "placement_dataset.csv"
# Read CSV file
df = pd.read_csv(CSV_PATH)
# 1. Display first 5 rows
print("FIRST 5 ROWS")
print(df.head())
# 2. Display dataset shape
print("\nDATASET SHAPE")
print(df.shape)
# 3. Display column names
print("\nCOLUMN NAMES")
print(df.columns)
# 4. Display data types
print("\nDATA TYPES")
print(df.dtypes)
# 5. Display basic information
print("\nDATASET INFORMATION")
df.info()
# 6. Display statistical summary
print("\nSTATISTICAL SUMMARY")
print(df.describe())
# 7. Check missing values
print("\nMISSING VALUES")
print(df.isnull().sum())
# 8. Check duplicate rows
print("\nDUPLICATE ROWS")
print(df.duplicated().sum())
# 9. Placement status distribution
print("\nPLACEMENT STATUS DISTRIBUTION")
print(df["Placed"].value_counts())
# 10. Placement status percentage
print("\nPLACEMENT STATUS PERCENTAGE")
print(df["Placed"].value_counts(normalize=True) * 100)
# Out:
# FIRST 5 ROWS
#    CGPA     IQ  Aptitude_Score  Communication_Skill  Internships Branch Placed
# 0  8.00   81.0            89.0                    1            1   MECH     No
# 1  7.36  105.0            74.0                    5            3  CIVIL    Yes
# 2  8.15   96.0            62.0                    6            1     IT     No
# 3  9.02  119.0            56.0                    6            2    CSE     No
# 4   NaN    NaN             NaN                    3            3    CSE    Yes
#
# DATASET SHAPE
# (200, 7)
#
# COLUMN NAMES
# Index(['CGPA', 'IQ', 'Aptitude_Score', 'Communication_Skill', 'Internships',
#        'Branch', 'Placed'],
#       dtype='object')
#
# DATA TYPES
# CGPA                   float64
# IQ                     float64
# Aptitude_Score         float64
# Communication_Skill      int64
# Internships              int64
# Branch                  object
# Placed                  object
# dtype: object
#
# DATASET INFORMATION
# ...
